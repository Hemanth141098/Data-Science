# %%
# Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
file_path = 'E:/Data Science Project/Unified Mentor Project/Intership Project/Project 8_ Employee Attrition Analysis/Attrition data.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
# Understanding the structure of the dataset
data.info()

# Statistical summary of numerical columns
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
# Handling missing values
data.dropna(inplace=True)

# Removing irrelevant columns
irrelevant_columns = ['EmployeeID', 'EmployeeCount', 'Over18', 'StandardHours']
data.drop(columns=irrelevant_columns, inplace=True)

# Confirming the changes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4300 entries, 0 to 4408
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4300 non-null   int64
#  1   Attrition                4300 non-null   object
#  2   BusinessTravel           4300 non-null   object
#  3   Department               4300 non-null   object
#  4   DistanceFromHome         4300 non-null   int64
#  5   Education                4300 non-null   int64
#  6   EducationField           4300 non-null   object
#  7   Gender                   4300 non-null   object
#  8   JobLevel                 4300 non-null   int64
#  9   JobRole                  4300 non-null   object
#  10  MaritalStatus            4300 non-null   object
#  11  MonthlyIncome            4300 non-null   int64
#  12  NumCompaniesWorked       4300 non-null   float64
#  13  PercentSalaryHike        4300 non-null   int64
# ...

# %%
print("\nMissing values after cleaning:")
print(data.isnull().sum())
# Out:
# Missing values after cleaning:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# dtype: int64

# %%
# Visualizing distributions of numerical columns
plt.figure(figsize=(14, 10))

plt.subplot(2, 2, 1)
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Distribution of Age')

plt.subplot(2, 2, 2)
sns.boxplot(x='Department', y='MonthlyIncome', data=data)
plt.title('Monthly Income Distribution by Department')

plt.subplot(2, 2, 3)
sns.countplot(x='Attrition', data=data, palette='Set2')
plt.title('Attrition Count')

plt.subplot(2, 2, 4)
sns.scatterplot(x='TotalWorkingYears', y='YearsAtCompany', data=data, hue='Attrition')
plt.title('Years at Company vs. Total Working Years')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\heman\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Histograms and distributions of numerical variables
plt.figure(figsize=(14, 12))

plt.subplot(3, 2, 1)
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Distribution of Age')

plt.subplot(3, 2, 2)
sns.histplot(data['MonthlyIncome'], bins=20, kde=True)
plt.title('Distribution of Monthly Income')

plt.subplot(3, 2, 3)
sns.histplot(data['TotalWorkingYears'], bins=20, kde=True)
plt.title('Distribution of Total Working Years')

plt.subplot(3, 2, 4)
sns.histplot(data['YearsAtCompany'], bins=20, kde=True)
plt.title('Distribution of Years at Company')

plt.subplot(3, 2, 5)
sns.histplot(data['JobSatisfaction'], bins=5, kde=True)
plt.title('Distribution of Job Satisfaction')

plt.subplot(3, 2, 6)
sns.histplot(data['WorkLifeBalance'], bins=5, kde=True)
plt.title('Distribution of Work-Life Balance')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\heman\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\heman\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\heman\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Pairplot for numerical variables
sns.pairplot(data[['Age', 'MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany', 'JobSatisfaction', 'WorkLifeBalance']])
plt.suptitle('Pairplot of Numerical Variables', y=1.02)
plt.show()
# Out:
# C:\Users\heman\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\heman\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\heman\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Selecting only numerical columns for correlation
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data[numerical_cols].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %%
# Count plots for categorical variables
plt.figure(figsize=(14, 10))

plt.subplot(3, 2, 1)
sns.countplot(x='Attrition', data=data, palette='Set1')
plt.title('Attrition Count')

plt.subplot(3, 2, 2)
sns.countplot(x='BusinessTravel', data=data, palette='Set2')
plt.title('Business Travel Frequency')

plt.subplot(3, 2, 3)
sns.countplot(x='Department', data=data, palette='Set3')
plt.title('Department Distribution')

plt.subplot(3, 2, 4)
sns.countplot(x='EducationField', data=data, palette='pastel')
plt.title('Education Field Distribution')

plt.subplot(3, 2, 5)
sns.countplot(x='Gender', data=data, palette='deep')
plt.title('Gender Distribution')

plt.subplot(3, 2, 6)
sns.countplot(x='MaritalStatus', data=data, palette='muted')
plt.title('Marital Status Distribution')

plt.tight_layout()
plt.show()

# %%
# Count plots for categorical variables
plt.figure(figsize=(14, 10))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(2, 4, i)
    sns.countplot(x=col, data=data, palette='Set3')
    plt.title(f'Count Plot of {col}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Summary statistics for numerical variables
summary_stats = data.describe()
print("Summary Statistics:")
print(summary_stats)
# Out:
# Summary Statistics:
#                Age  DistanceFromHome    Education     JobLevel  MonthlyIncome  \
# count  4300.000000       4300.000000  4300.000000  4300.000000    4300.000000
# mean     36.926977          9.197907     2.913256     2.066977   65059.844186
# std       9.146517          8.097059     1.024774     1.106633   47045.398914
# min      18.000000          1.000000     1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000     1.000000   29260.000000
# 50%      36.000000          7.000000     3.000000     2.000000   49360.000000
# 75%      43.000000         14.000000     4.000000     3.000000   83802.500000
# max      60.000000         29.000000     5.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count         4300.000000        4300.000000       4300.000000
# mean             2.690000          15.210698          0.795349
# ...

# %%
# Correlation matrix for numerical variables
correlation_matrix = data[numerical_cols].corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                               Age  DistanceFromHome  Education  JobLevel  \
# Age                      1.000000          0.004621  -0.034452 -0.000781
# DistanceFromHome         0.004621          1.000000  -0.006369 -0.038576
# Education               -0.034452         -0.006369   1.000000  0.043686
# JobLevel                -0.000781         -0.038576   0.043686  1.000000
# MonthlyIncome           -0.047256         -0.019798   0.006381  0.045015
# NumCompaniesWorked       0.303709         -0.016336  -0.018156 -0.008314
# PercentSalaryHike       -0.034313          0.035857  -0.043592  0.010119
# StockOptionLevel        -0.030608          0.007376   0.000443  0.002940
# TotalWorkingYears        0.681213          0.004364  -0.008236 -0.035378
# TrainingTimesLastYear   -0.032032         -0.006383   0.009327 -0.032476
# YearsAtCompany           0.314384          0.030998   0.008297 -0.064122
# YearsSinceLastPromotion  0.216554          0.001888   0.026970 -0.058601
# ...

# %%
# Assuming 'data' is your cleaned DataFrame and 'file_path' is the original file location
file_path = 'E:/Data Science Project/Unified Mentor Project/Intership Project/Project 8_ Employee Attrition Analysis/Attrition data.csv'

# Export the DataFrame to CSV
data.to_csv(file_path, index=False)

print(f"Data successfully exported to {file_path}")
# Out:
# Data successfully exported to E:/Data Science Project/Unified Mentor Project/Intership Project/Project 8_ Employee Attrition Analysis/Attrition data.csv
